# %% [markdown]
# #Review of Last Week's Homework

# %%
#Question 4 from Homework

#Create two variables. One for your name and one for your age. Now use the print() function to print your name
#and age using variables in the print function. Only use one print() function to do this.

name = "bob"
age = 10

print("My name is {} and my age is {}".format(name,age))

#Question 5

"""
Create a variable called apples which equals 10. Create a variable called oranges which equal 5.
Create another variable called total_fruit which adds apples and oranges together.

Then print all your variables in one line and make the output identical to:
“There are 10 apples and 5 oranges and 15 fruit all together!”

"""

apples = 10
oranges = 5
total_fruit = apples+oranges

print("There are {} apples and {} oranges and {} fruit all together".format(apples,oranges,total_fruit))
# Out:
# My name is bob and my age is 10
# There are 10 apples and 5 oranges and 15 fruit all together

# %% [markdown]
# Variable Assignment Review

# %%
dogs = 10
cats = 7
birds = 6

total = dogs+cats+birds

#Using comma method
print("You have",dogs,"dogs,", cats, "cats," " and", birds,"birds!" " That's", total, "items in total!")

#Using .format method
print("You have {} dogs, {} cats, and {} birds. That's {} items in total!".format(dogs,cats,birds,total))

# %% [markdown]
# Using the Input Function

# %%
#Example 1

name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Your name is {} and your age is {}".format(name,age))
# Out:
# Enter your name: Bob
# Enter your age: 10
# Your name is Bob and your age is 10

# %%
#Example 1.5

apples = int(input("How many apples do you have? "))
bananas = int(input("How many bananas do you have? "))
total_fruit = apples+bananas

print(total_fruit)
# Out:
# How many apples do you have? 10
# How many bananas do you have? 5
# 15

# %%
#Question 2:
#Use the input function to store three variables – user's name, pet, and pet_name. Then, print out the user’s name,
#type of pet (like dog or cat), and the name of their pet. Use the print function and ensure that the final output is only on one line of code.

name = input("What is your name?: ")
pet = input("What type of pet do you have?: ")
pet_name = input("What is your pet's name?: ")



print("Your name is {} and you have a pet {} whose name is {}!".format(name,pet,pet_name))
# Out:
# How old are you?15

# %%
#Question 3 - Advanced:
#Use the input function to store two variables – name, age in years. Then create a new variable with age in days.
#Then, print out the user’s name and ages on one line using the print function.

#Hint: Because python stores all values from the int() function as string, we want to convert those values to integer before doing any calculations.


name = input("Enter your name: ")
age = int(input("Enter your age in years: "))
age_days = age * 365

print("Your name is {} and your age is {} and your age in days is {}".format(name,age, age_days))

# %% [markdown]
# #Functions

# %%
#Example 1
#Create a function which prints my name and age
def name_age()
  print("My name is Bob")\
  print("My age is 10")


#Calling the function
name_age()



#Example 2
#Creating the function
def print_twice(string):
  print(string)
  print(string)
  print(string)

#Calling the function
print_twice("Hello")
# Out:
# Hello
# Hello
# Hello
